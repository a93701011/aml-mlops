# %% [markdown]
# ## Hands-on Workshop
# ## Leverage Best Model from AutoML Run Results

# %% [markdown]
# ## Setup Project Workspace
#
# Azure ML:
# [Workspace](https://docs.microsoft.com/en-us/python/api/azureml-core/azureml.core.workspace.workspace?view=azure-ml-py) class definition

# %%
import azureml.core
from azureml.core import Workspace
import pandas as pd

from azureml.core.authentication import ServicePrincipalAuthentication

sp = ServicePrincipalAuthentication(tenant_id="72f988bf-86f1-41af-91ab-2d7cd011db47", # tenantID
                                    service_principal_id="2cfbcca2-c1a0-4e4a-a43e-2ac27f068242", # clientId
                                    service_principal_password = dbutils.secrets.get(scope = 'karenkeyvault', key = 'sp-example-app-karenku-secret')
                                   )
# sepcficy workspace using current active config
subscription_id = '09ba1f2e-4799-434c-9f88-6ca60b368ac8'
resource_group = 'mlservicedemo'
workspace_name = 'mlservicedemo'

workspace = Workspace(subscription_id, resource_group, workspace_name, auth = sp)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from azureml.core import Experiment

# setup Experiment for tracking
experiment_name = 'airbnb_clean_auto'
exp = Experiment(workspace=workspace, name=experiment_name)
exp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: </div>
# <table style="width:100%"><tr><th>Name</th><th>Workspace</th><th>Report Page</th><th>Docs Page</th></tr><tr><td>airbnb_clean_auto</td><td>mlservicedemo</td><td><a href="https://ml.azure.com/experiments/id/4f747689-f09a-4516-974f-0337e9e39f4d?wsid=/subscriptions/09ba1f2e-4799-434c-9f88-6ca60b368ac8/resourcegroups/mlservicedemo/workspaces/mlservicedemo&amp;tid=72f988bf-86f1-41af-91ab-2d7cd011db47" target="_blank" rel="noopener">Link to Azure Machine Learning studio</a></td><td><a href="https://docs.microsoft.com/en-us/python/api/azureml-core/azureml.core.experiment.Experiment?view=azure-ml-py" target="_blank" rel="noopener">Link to Documentation</a></td></tr></table>

# %% [markdown]
# #### (1) Fetch Run Information

# %%
from azureml.core.run import Run
from azureml.train.automl.run import AutoMLRun

# specify the best run's RUN ID from AutoML result page
# we can also programmatically search for the best run given a target metric of interest
run_id = 'AutoML_f6aab62f-5c37-49b4-b6c0-cc6e475a9be9'

# get run details
run = AutoMLRun(experiment=exp, run_id=run_id)
run.get_details()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: {&#39;runId&#39;: &#39;AutoML_f6aab62f-5c37-49b4-b6c0-cc6e475a9be9&#39;,
#  &#39;target&#39;: &#39;dev-cluster&#39;,
#  &#39;status&#39;: &#39;Completed&#39;,
#  &#39;startTimeUtc&#39;: &#39;2022-04-27T09:40:26.504854Z&#39;,
#  &#39;endTimeUtc&#39;: &#39;2022-04-27T10:32:45.893815Z&#39;,
#  &#39;services&#39;: {},
#  &#39;warnings&#39;: [{&#39;source&#39;: &#39;JasmineService&#39;,
#    &#39;message&#39;: &#39;No scores improved over last 20 iterations, so experiment stopped early. This early stopping behavior can be disabled by setting enable_early_stopping = False in AutoMLConfig for notebook/python SDK runs.&#39;}],
#  &#39;properties&#39;: {&#39;num_iterations&#39;: &#39;1000&#39;,
#   &#39;training_type&#39;: &#39;TrainFull&#39;,
#   &#39;acquisition_function&#39;: &#39;EI&#39;,
#   &#39;primary_metric&#39;: &#39;normalized_root_mean_squared_error&#39;,
#   &#39;train_split&#39;: &#39;0&#39;,
#   &#39;acquisition_parameter&#39;: &#39;0&#39;,
#   &#39;num_cross_validation&#39;: &#39;5&#39;,
#   &#39;target&#39;: &#39;dev-cluster&#39;,
#   &#39;AMLSettingsJsonString&#39;: &#39;{&#34;enable_early_stopping&#34;:true,&#34;enable_ensembling&#34;:true,&#34;enable_stack_ensembling&#34;:true,&#34;ensemble_iterations&#34;:15,&#34;enable_onnx_compatible_models&#34;:false,&#34;max_cores_per_iteration&#34;:-1,&#34;send_telemetry&#34;:true,&#34;blacklist_algos&#34;:[&#34;TensorFlowDNN&#34;,&#34;TensorFlowLinearRegressor&#34;],&#34;whitelist_models&#34;:null,&#34;compute_target&#34;:&#34;dev-cluster&#34;,&#34;enable_dnn&#34;:false,&#34;enable_code_generation&#34;:true,&#34;experiment_exit_score&#34;:null,&#34;experiment_timeout_minutes&#34;:360,&#34;featurization&#34;:&#34;auto&#34;,&#34;hyperdrive_config&#34;:null,&#34;grain_column_names&#34;:null,&#34;is_timeseries&#34;:false,&#34;iteration_timeout_minutes&#34;:360,&#34;max_concurrent_iterations&#34;:2,&#34;metric_operation&#34;:&#34;minimize&#34;,&#34;model_explainability&#34;:true,&#34;n_cross_validations&#34;:null,&#34;name&#34;:&#34;airbnb_clean_auto&#34;,&#34;path&#34;:&#34;./sample_projects/airbnb_clean_auto&#34;,&#34;primary_metric&#34;:&#34;normalized_root_mean_squared_error&#34;,&#34;region&#34;:&#34;japaneast&#34;,&#34;resource_group&#34;:&#34;mlservicedemo&#34;,&#34;subscription_id&#34;:&#34;09ba1f2e-4799-434c-9f88-6ca60b368ac8&#34;,&#34;task_type&#34;:&#34;regression&#34;,&#34;validation_size&#34;:null,&#34;test_size&#34;:null,&#34;vm_type&#34;:&#34;STANDARD_DS11_V2&#34;,&#34;workspace_name&#34;:&#34;mlservicedemo&#34;,&#34;label_column_name&#34;:&#34;price&#34;,&#34;save_mlflow&#34;:true,&#34;enable_batch_run&#34;:true,&#34;dataset_id&#34;:&#34;186cb751-b515-4ea6-a90c-eb5443f07e9d&#34;}&#39;,
#   &#39;DataPrepJsonString&#39;: &#39;{\\&#34;datasets\\&#34;:0,\\&#34;training_data\\&#34;:{\\&#34;datasetId\\&#34;:\\&#34;186cb751-b515-4ea6-a90c-eb5443f07e9d\\&#34;}}&#39;,
#   &#39;EnableSubsampling&#39;: &#39;False&#39;,
#   &#39;runTemplate&#39;: &#39;AutoML&#39;,
#   &#39;azureml.runsource&#39;: &#39;automl&#39;,
#   &#39;_aml_system_scenario_identification&#39;: &#39;Remote.Parent&#39;,
#   &#39;ClientType&#39;: &#39;Browser&#39;,
#   &#39;environment_cpu_name&#39;: &#39;AzureML-AutoML&#39;,
#   &#39;environment_cpu_label&#39;: &#39;prod&#39;,
#   &#39;environment_gpu_name&#39;: &#39;AzureML-AutoML-GPU&#39;,
#   &#39;environment_gpu_label&#39;: &#39;prod&#39;,
#   &#39;root_attribution&#39;: &#39;automl&#39;,
#   &#39;attribution&#39;: &#39;AutoML&#39;,
#   &#39;Orchestrator&#39;: &#39;AutoML&#39;,
#   &#39;CancelUri&#39;: &#39;https://japaneast.api.azureml.ms/jasmine/v1.0/subscriptions/09ba1f2e-4799-434c-9f88-6ca60b368ac8/resourceGroups/mlservicedemo/providers/Microsoft.MachineLearningServices/workspaces/mlservicedemo/experiment/airbnb_clean_auto/cancel/AutoML_f6aab62f-5c37-49b4-b6c0-cc6e475a9be9&#39;,
#   &#39;ClientSdkVersion&#39;: &#39;1.40.0.post1&#39;,
#   &#39;snapshotId&#39;: &#39;00000000-0000-0000-0000-000000000000&#39;,
#   &#39;SetupRunId&#39;: &#39;AutoML_f6aab62f-5c37-49b4-b6c0-cc6e475a9be9_setup&#39;,
#   &#39;SetupRunContainerId&#39;: &#39;dcid.AutoML_f6aab62f-5c37-49b4-b6c0-cc6e475a9be9_setup&#39;,
#   &#39;FeaturizationRunJsonPath&#39;: &#39;featurizer_container.json&#39;,
#   &#39;FeaturizationRunId&#39;: &#39;AutoML_f6aab62f-5c37-49b4-b6c0-cc6e475a9be9_featurize&#39;,
#   &#39;ProblemInfoJsonString&#39;: &#39;{&#34;dataset_num_categorical&#34;: 0, &#34;is_sparse&#34;: true, &#34;subsampling&#34;: false, &#34;has_extra_col&#34;: true, &#34;dataset_classes&#34;: 375, &#34;dataset_features&#34;: 113, &#34;dataset_samples&#34;: 4707, &#34;single_frequency_class_detected&#34;: false}&#39;,
#   &#39;ModelExplainRunId&#39;: &#39;AutoML_f6aab62f-5c37-49b4-b6c0-cc6e475a9be9_ModelExplain&#39;},
#  &#39;inputDatasets&#39;: [{&#39;dataset&#39;: {&#39;id&#39;: &#39;186cb751-b515-4ea6-a90c-eb5443f07e9d&#39;}, &#39;consumptionDetails&#39;: {&#39;type&#39;: &#39;RunInput&#39;, &#39;inputName&#39;: &#39;training_data&#39;, &#39;mechanism&#39;: &#39;Direct&#39;}}],
#  &#39;outputDatasets&#39;: [],
#  &#39;logFiles&#39;: {},
#  &#39;submittedBy&#39;: &#39;Karen Ku&#39;}</div>

# %% [markdown]
# **Register Model**

# %%
best_child_run = run.get_best_child()

model_name = best_child_run.properties["model_name"]
model_output_path = best_child_run.properties["model_output_path"]
print(f'Found best model: {model_name} ({model_output_path})')

model = best_run.register_model(
    model_name=model_name, model_path=model_output_path
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">WARNING:root:Received unrecognized parameter grain_column_names
# WARNING:root:Received unrecognized parameter grain_column_names
# Found best model: AutoMLf6aab62f558 (outputs/model.pkl)
# </div>

# %% [markdown]
# #### (2) Fetch Model Artifacts

# %%
from azureml.core.model import Model
import os

best_child_run = run.get_best_child()

# get best model's information from run details
model_name = best_child_run.properties["model_name"]
model_output_path = best_child_run.properties["model_output_path"]

# retrieve best model
best_model = Model(workspace=workspace, name=model_name)

# download the model to local project (on local compute instance)
print('\nDownloading to local compute instance...')
best_model.download(target_dir=os.path.join(os.getcwd(), 'outputs'), exist_ok=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
# Downloading to local compute instance...
# Out[10]: &#39;/databricks/driver/outputs/model.pkl&#39;</div>

# %% [markdown]
# #### (3) Fetch build environment definition (YAML)

# %%
import os

# fetch conda environment yaml definition from Run context
url = best_child_run.properties['conda_env_data_location']
print(url)

# download it from the 'outputs' directory managed by AzureML (for all run artifacts)
base_name = os.path.basename(url)
best_run.download_file(os.path.join('outputs', base_name),'conda_env_v_1_0_0.yml')

print('Fetched Conda environment yaml for restoring the build of the Best Run')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">aml://artifact/ExperimentRun/dcid.AutoML_f6aab62f-5c37-49b4-b6c0-cc6e475a9be9_58/outputs/conda_env_v_1_0_0.yml
# Fetched Conda environment yaml for restoring the build of the Best Run
# </div>

# %%
from azureml.core import Environment
env = Environment.from_conda_specification(name='automl-airbnb-train-env', file_path='./conda_env_v_1_0_0.yml')
env
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: {
#     &#34;databricks&#34;: {
#         &#34;eggLibraries&#34;: [],
#         &#34;jarLibraries&#34;: [],
#         &#34;mavenLibraries&#34;: [],
#         &#34;pypiLibraries&#34;: [],
#         &#34;rcranLibraries&#34;: []
#     },
#     &#34;docker&#34;: {
#         &#34;arguments&#34;: [],
#         &#34;baseDockerfile&#34;: null,
#         &#34;baseImage&#34;: &#34;mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220412.v1&#34;,
#         &#34;baseImageRegistry&#34;: {
#             &#34;address&#34;: null,
#             &#34;password&#34;: null,
#             &#34;registryIdentity&#34;: null,
#             &#34;username&#34;: null
#         },
#         &#34;enabled&#34;: false,
#         &#34;platform&#34;: {
#             &#34;architecture&#34;: &#34;amd64&#34;,
#             &#34;os&#34;: &#34;Linux&#34;
#         },
#         &#34;sharedVolumes&#34;: true,
#         &#34;shmSize&#34;: &#34;2g&#34;
#     },
#     &#34;environmentVariables&#34;: {
#         &#34;EXAMPLE_ENV_VAR&#34;: &#34;EXAMPLE_VALUE&#34;
#     },
#     &#34;inferencingStackVersion&#34;: null,
#     &#34;name&#34;: &#34;automl-airbnb-train-env&#34;,
#     &#34;python&#34;: {
#         &#34;baseCondaEnvironment&#34;: null,
#         &#34;condaDependencies&#34;: {
#             &#34;channels&#34;: [
#                 &#34;anaconda&#34;,
#                 &#34;conda-forge&#34;
#             ],
#             &#34;dependencies&#34;: [
#                 &#34;python=3.7.9&#34;,
#                 {
#                     &#34;pip&#34;: [
#                         &#34;azureml-train-automl-runtime==1.40.0.post1&#34;,
#                         &#34;inference-schema&#34;,
#                         &#34;azureml-interpret==1.40.0&#34;,
#                         &#34;azureml-defaults==1.40.0&#34;
#                     ]
#                 },
#                 &#34;numpy==1.18.5&#34;,
#                 &#34;pandas==1.1.5&#34;,
#                 &#34;scikit-learn==0.22.1&#34;,
#                 &#34;py-xgboost==1.3.3&#34;,
#                 &#34;fbprophet==0.7.1&#34;,
#                 &#34;holidays==0.10.3&#34;,
#                 &#34;psutil==5.7.2&#34;
#             ],
#             &#34;name&#34;: &#34;project_environment&#34;
#         },
#         &#34;condaDependenciesFile&#34;: null,
#         &#34;interpreterPath&#34;: &#34;python&#34;,
#         &#34;userManagedDependencies&#34;: false
#     },
#     &#34;r&#34;: null,
#     &#34;spark&#34;: {
#         &#34;packages&#34;: [],
#         &#34;precachePackages&#34;: true,
#         &#34;repositories&#34;: []
#     },
#     &#34;version&#34;: null
# }</div>

# %% [markdown]
# #### (4) Fetch Scoring Function (score.py)
#
# **IMPORTANT**
# This is a sample produced by AutoML, do NOT use it if we plan to include custom data preprocessing steps in the inference process such as this workshop

# %%
import os

# fetch sample score.py produced by Run context
url = best_child_run.properties['scoring_data_location']
print(url)

# download it from the 'outputs' directory managed by AzureML (for all run artifacts)
base_name = os.path.basename(url)
best_run.download_file(os.path.join('outputs', base_name), base_name)

print(f'Fetched Scoring Funciton ({base_name}) built by AutoML from Best Run')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">aml://artifact/ExperimentRun/dcid.AutoML_f6aab62f-5c37-49b4-b6c0-cc6e475a9be9_58/outputs/scoring_file_v_1_0_0.py
# Fetched Scoring Funciton (scoring_file_v_1_0_0.py) built by AutoML from Best Run
# </div>

# %%
# %sh ls /databricks/driver/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ## Model Build, Package, Release and Deploy (CI/CD) with AzureML
#
# Following is executed using AzureML's built-in MLOps features
#
# * Package all required dependencies, artifacts and model
# * Generate docker build file
# * Instantiate Flask/Gunicor and Nginx based webservice
# * Build images
# * Register image and push to private container registry
# * Setup target inference compute (ACI/AKS/AzureMLCompute/Databricks)
# * Deploy
# * Logging and managed endpoint monitoring

# %%
import sklearn
from azureml.core.model import InferenceConfig
from azureml.core.webservice import AciWebservice
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies

# reuse build environment from earlier steps 
env = Environment.from_conda_specification(name='automl-airbnb-train-env', file_path='./conda_env_v_1_0_0.yml')


# setup inference runtime config
inference_config = InferenceConfig(entry_script='./scoring_file_v_1_0_0.py', environment=env)

# setup inference target config (Azure Container Instance)
aci_config = AciWebservice.deploy_configuration(cpu_cores=1, memory_gb=1)
service_name = 'automl-airbnb'

# trigger deployment (can also be controled with AzCLI in addition to PythonSDK for integration with external CI/CD pipelines)
service = Model.deploy(workspace=workspace,
                       name=service_name,
                       models=[best_model],
                       inference_config=inference_config,
                       deployment_config=aci_config,
                       overwrite=True)

service.wait_for_deployment(show_output=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
