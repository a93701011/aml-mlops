# %%
# in the databrick also can use accesskey or sasurl

# spark.conf.set(
#   "fs.azure.account.key.<storage-account-name>.blob.core.windows.net",
#   "<storage-account-access-key>")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
spark.conf.set(
  "fs.azure.sas.amldata.storageblobdatabrick.blob.core.windows.net",
  "?sv=2020-08-04&ss=bfqt&srt=sco&sp=rwdlacupitfx&se=2022-04-29T22:09:48Z&st=2022-04-17T14:09:48Z&spr=https&sig=ndQ65k3K5xSn%2BCRm341mc474z1rU5YZmX3CNivKG1Yk%3D")
df = spark.read.option('header',True).csv("wasbs://amldata@storageblobdatabrick.blob.core.windows.net/airbnb-cleaned-mlflow.csv")
display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
